# %%
import os
import re
import json
import matplotlib.pyplot as plt
import numpy as np
import string
import pandas as pd
import pyspark.sql.functions as F
import nltk
import cPickle as pickle

from os import listdir
from os.path import isfile, join
from scipy.sparse import csr_matrix
from sklearn.metrics import mean_squared_error
from sklearn.manifold import TSNE
from itertools import chain
from scipy.sparse import coo_matrix
from pyspark.mllib.linalg.distributed import CoordinateMatrix, MatrixEntry, IndexedRow, IndexedRowMatrix
from pyspark.sql import Row
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import SGDClassifier, RidgeClassifierCV
from operator import add
from pyspark.sql.functions import udf
from pyspark.sql import SparkSession
from pyspark.sql.types import IntegerType, FloatType
from __future__ import print_function, unicode_literals, with_statement, absolute_import, generators, nested_scopes, division
from pyspark.sql.functions import mean, stddev
# %matplotlib notebook

# %%
# Local Spark
# spark session is now the entry point of spark program
# for line 8, can use local[n] for run spark locally with n cores

runLocal = True
if runLocal == True:
    spark = SparkSession.builder \
        .master('local[10]') \
        .appName("Word Count") \
        .config("spark.driver.maxResultSize", "15g")\
        .getOrCreate()
else:
    #p = subprocess.Popen(['sinteractive', '--partition=broadwl', '--cpus-per-task=10', '--time=00:30:00'], stdout=subprocess.PIPE, shell = True)
    #print(p.stdout.read())
    # start spark master program on this machine and register worker nodes
    os.system('start-spark-slurm.sh&') # use & to put it into background
    # get ip address of this machine
    ip = os.popen('hostname -i').read().strip('\n')
    # change 'local' to be ip of master node
    spark = SparkSession.builder \
        .master('spark://' + ip + ':7077') \
        .appName('Word Count') \
        .config("spark.driver.maxResultSize", "15g")\
        .getOrCreate()
    print('Spark Session web UI: http://{}:4040'.format(ip))

# %%
wiki_file = open('/project/cmsc25025/wikipedia/wiki-text.txt','r').readlines()[0]
num_chunks = 10 #make it multiple of number of your cores
chunks, chunk_size = len(wiki_file), int(len(wiki_file)/num_chunks)
wiki_chunks = [wiki_file[i:i+chunk_size] for i in range(0, chunks, chunk_size)]
wiki_data = spark.sparkContext.parallelize(wiki_chunks)

# %% [markdown]
# # Get vocab

# %%
def trans(t):
    return t.lower().encode('utf-8').translate(string.maketrans("",""), string.punctuation).strip().split()

def normlizeStr(text, stopwordLst = None, stemmer = None):
    
    sents = nltk.sent_tokenize(text)
    tl = [nltk.word_tokenize(s) for s in sents]
    tokenLst = list(chain(*tl))
    
    #Lowering the case and removing non-words
    workingIter = (w.lower() for w in tokenLst if w.isalpha())

    #Now we can use the semmer, if provided
    if stemmer is not None:
        workingIter = (stemmer.stem(w) for w in workingIter)
        
    #And remove the stopwords
    if stopwordLst is not None:
        workingIter = (w for w in workingIter if w not in stopwordLst)
            
    return list(workingIter)

#initialize our stemmer and our stop words
stop_words_nltk = nltk.corpus.stopwords.words('english')
snowball = nltk.stem.snowball.SnowballStemmer('english')
wordnet = nltk.stem.WordNetLemmatizer()

# def rmv(l):
#     l = filter(lambda a: (a in vocab)==True, l)

# %%
words = wiki_data.flatMap(lambda x: trans(x)).collect()
word_dict = nltk.FreqDist(words)
for key in word_dict.keys():
    if word_dict[key] <= 500:
        word_dict.pop(key, None)
#len(word_dict): 13343
vocab = sorted(word_dict.keys())
vocab_dim = len(vocab)

# %%
wiki = wiki_data.flatMap(lambda x: trans(x)).filter(lambda a: (a in vocab)==True).collect()

# %%
#wikiRDD_ = wikiRDD.filter(lambda a: (a in vocab)==True).cache()

# %%
wiki[:5]
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term']

# %%
with open("vocab.txt", "w") as v_file:
    for item in vocab:
        v_file.write(item + ", ")

# %%
with open("wiki.txt", "w") as text_file:
    for item in wiki:
        text_file.write(item + ", ")

# %% [markdown]
# # PMI Embeddings

# %%
M = csr_matrix((vocab_dim, vocab_dim), dtype=np.int8)

# %%
vect_dict = {}
for i in range(vocab_dim):
    data = np.array([1])
    row = np.array([i])
    col = np.array([0])
    vect_dict[vocab[i]] = csr_matrix((data, (row, col)), (vocab_dim, 1))

# %%
text_len = len(wiki)

# %%
for i in range(text_len):
    this_word = wiki[i]
    index = vocab.index(this_word)
    if i<5:
        context = wiki[:i+5]
    elif i>text_len-5:
        context = wiki[i-5:]
    else:
        context = wiki[i-5:i+5]
    count_vect = csr_matrix((vocab_dim, 1), dtype=np.int8)
    for word in context:
        if word != wiki[i]:
            count_vect += vect_dict[word]
    #print()
    M[index] += count_vect.T

# %%
vocab.index("aa")
# Out:
# 1

# %%
count_vect.T.shape
# Out:
# (1, 13343)

# %% [markdown]
# (b)Factorize M to obtain word embeddings

# %%
U, s, V = scipy.sparse.linalg.svds(scipy.sparse.csr(M), k=50)

# %% [markdown]
# # Glove

# %%
#pretrained 
p_vectors_file = 'glove.6B.50d.txt'

with open(p_vectors_file, 'r') as f:
    p_vectors = {}
    for line in f:
        try:
            vals = line.rstrip().split(' ')
            p_vectors[vals[0]] = [float(x) for x in vals[1:]]
        except ValueError:
            continue
p_vectsRDD = spark.sparkContext.parallelize(p_vectors.items())

# %%
len(p_vectors)
# Out:
# 390034

# %% [markdown]
# # Experiments
#
# - the PMI embeddings
# - the local GloVe embeddings
# - the downloaded pretrained GloVe embeddings
#
# ## (a) Read your local GloVe embeddings

# %%
vocab_file   = 'GloVe/wiki-vocab.txt'
vectors_file = 'GloVe/wiki-vectors.txt'

with open(vocab_file, 'r') as f:
    words = [x.rstrip().split(' ')[0] for x in f.readlines()]

with open(vectors_file, 'r') as f:
    vectors = {}
    for line in f:
        vals = line.rstrip().split(' ')
        vectors[vals[0]] = [float(x) for x in vals[1:]]
        
vocabulary  = {w: idx for idx, w in enumerate(words)}
ivocabulary = {idx: w for idx, w in enumerate(words)}

vectsRDD = spark.sparkContext.parallelize(vectors.items())

# %% [markdown]
# ## (b) For each of the following words, find the 5 closest words in the embedding space:
# physics, republican, einstein, algebra, fish.
#
# Report and comment on your results and the differences between the three sets of embeddings.

# %%
def find_closest(v, n, label):
    if label == 'local':
        vect = vectors
        RDD = vectsRDD
    elif label == "pre":
        vect = p_vectors
        RDD = p_vectsRDD        
    
    if type(v)== type(' '):
        v = np.array(vect[v])
        
    rdd = RDD.map(lambda x: (x[0], mean_squared_error(v,np.array(x[1]))))
    tuples = sorted(rdd.collect(), key=lambda x: x[1])[1:1+n]
    words = [x[0] for x in tuples]
    return words

# %%
word_list = ['physics', 'republican', 'einstein', 'algebra', 'fish']
print("Results from local GloVe embeddings:")
for word in word_list:
    print(word, ": ", find_closest(word,5, 'local'), sep = '')

print("\nResults from pretrained GloVe embeddings:")
for word in word_list:
    print(word, ": ", find_closest(word,5, 'pre'), sep = '')
# Out:
# Results from local GloVe embeddings:
# physics: [u'mechanics', u'chemistry', u'mathematics', u'quantum', u'theoretical']
# republican: [u'democrat', u'senator', u'representative', u'republicans', u'democrats']
# einstein: [u'relativity', u'maxwell', u'bose', u'formulated', u'condensate']
# algebra: [u'algebraic', u'algebras', u'mathematics', u'finite', u'boolean']
# fish: [u'feed', u'fresh', u'hunting', u'salmon', u'wild']
#
# Results from pretrained GloVe embeddings:
# physics: [u'chemistry', u'mathematics', u'theoretical', u'science', u'biology']
# republican: [u'gop', u'democrat', u'democratic', u'republicans', u'democrats']
# einstein: [u'bohr', u'relativity', u'invented', u'freud', u'gottlieb']
# algebra: [u'geometry', u'homological', u'algebraic', u'associative', u'analytic']
# fish: [u'salmon', u'shrimp', u'meat', u'bird', u'wild']

# %% [markdown]
# ## (c) france :  paris ::  england :  ?

# %%
def get_analogy(a,b,c,local):
    if local == True:
        v = np.array(vectors[b])-np.array(vectors[a])+np.array(vectors[c])
        print("Result from local GloVe embeddings:", find_closest(v,1,'local')[0])
    p_v = np.array(p_vectors[b])-np.array(p_vectors[a])+np.array(p_vectors[c])
    print("Result from pretrained GloVe embeddings:", find_closest(p_v,1,"pre")[0])

# %%
get_analogy('france','paris','england', True)
# Out:
# Result from local GloVe embeddings: edinburgh
# Result from pretrained GloVe embeddings: london

# %% [markdown]
# ## (d) Analogies

# %%
path = '/project/cmsc25025/assn4_analogy'
files = [f for f in listdir(path) if isfile(join(path, f))]

# %%
def rmv(t):
    words = filter(lambda x: x!= "", re.split('[^a-zA-Z]', t))
    return words

# %%
analogies = []
for fi in files:
    with open(path+"/"+fi, 'r') as f:
        words = [rmv(x) for x in f.readlines()]
        analogies+= words

# %%
for analogy in analogies:
    try: 
        a, b, c = analogy
        print(a+' : '+b+' = '+c+": ?")
    except: 
        print("Wrong format of the analogy\n")
        
    try:
        get_analogy(a,b,c, False)
    except:
        print("Word not in library.\n")
        continue
    print()
# Out:
# segregate : unify = damage: ?
# Result from pretrained GloVe embeddings: overcome
#
# argentina : brazil = iran: ?
# Result from pretrained GloVe embeddings: tehran
#
# ashes : urn = money: ?
# Result from pretrained GloVe embeddings: paying
#
# telephone : cord = television: ?
# Result from pretrained GloVe embeddings: spinal
#
# walk : roam = speak: ?
# Result from pretrained GloVe embeddings: resent
#
# novel : epilogue = meal: ?
# Result from pretrained GloVe embeddings: meal
#
# chinese : china = french: ?
# Result from pretrained GloVe embeddings: french
#
# evening : morning = dinner: ?
# Result from pretrained GloVe embeddings: lunch
#
# left : right = horizontal: ?
# Result from pretrained GloVe embeddings: vertical
#
# theorem : deduce = hypothesis: ?
# Result from pretrained GloVe embeddings: decipher
#
# h : water = bird: ?
# Result from pretrained GloVe embeddings: fish
#
# chicken : egg = cow: ?
# Result from pretrained GloVe embeddings: cloned
#
# go : green = stop: ?
# Result from pretrained GloVe embeddings: yellow
#
# chicago : illinois = dallas: ?
# Result from pretrained GloVe embeddings: illinois
#
# library : book = resturant: ?
# Word not in library.
#
# dessert : meal = revelations: ?
# Result from pretrained GloVe embeddings: abuse
#
# chef : knife = student: ?
# Result from pretrained GloVe embeddings: gun
#
# cookies : milk = chips: ?
# Result from pretrained GloVe embeddings: chips
#
# math : physics = calculus: ?
# Result from pretrained GloVe embeddings: relativity
#
# Wrong format of the analogy
#
# Result from pretrained GloVe embeddings: relativity
#
# thor : loki = hammer: ?
# Result from pretrained GloVe embeddings: shove
#
# odin : hela = asgard: ?
# Result from pretrained GloVe embeddings: stroma
#
# beijing : shanghai = tiananmen: ?
# Result from pretrained GloVe embeddings: pagoda
#
# detroit : chicago = car: ?
# Result from pretrained GloVe embeddings: driving
#
# earth : mars = human: ?
# Result from pretrained GloVe embeddings: cites
#
# ice : fire = cold: ?
# Result from pretrained GloVe embeddings: attack
#
# lannister : stark = tywin: ?
# Result from pretrained GloVe embeddings: suggests
#
# uchicago : northwestern = smart: ?
# Word not in library.
#
# physics : astronomy = chemistry: ?
# Result from pretrained GloVe embeddings: chemistry
#
# good : better = bad: ?
# Result from pretrained GloVe embeddings: worse
#
# eat : happy = run: ?
# Result from pretrained GloVe embeddings: career
#
# healthy : vegetable = unhealthy: ?
# Result from pretrained GloVe embeddings: perishable
#
# rubber : elastic = glass: ?
# Result from pretrained GloVe embeddings: three-dimensional
#
# star : planet = nuclei: ?
# Result from pretrained GloVe embeddings: atoms
#
# night : black = day: ?
# Result from pretrained GloVe embeddings: white
#
# wolf : dog = tiger: ?
# Result from pretrained GloVe embeddings: dog
#
# canada : america = germany: ?
# Result from pretrained GloVe embeddings: europe
#
# china : tea = france: ?
# Result from pretrained GloVe embeddings: bordeaux
#
# left : right = up: ?
# Result from pretrained GloVe embeddings: right
#
# dog : cat = puppy: ?
# Result from pretrained GloVe embeddings: kitten
#
# finger : hand = toe: ?
# Result from pretrained GloVe embeddings: hand
#
# page : book = finger: ?
# Result from pretrained GloVe embeddings: fingers
#
# day : night = up: ?
# Result from pretrained GloVe embeddings: out
#
# hard : easy = awake: ?
# Result from pretrained GloVe embeddings: waking
#
# brain : body = engine: ?
# Result from pretrained GloVe embeddings: chassis
#
# cereal : milk = butter: ?
# Result from pretrained GloVe embeddings: mixture
#
# street : city = vein: ?
# Result from pretrained GloVe embeddings: cerebral
#
# happy : sad = smile: ?
# Result from pretrained GloVe embeddings: sad
#
# japan : sushi = mexico: ?
# Result from pretrained GloVe embeddings: tasting
#
# economics : finance = mathematics: ?
# Result from pretrained GloVe embeddings: addition
#
# basketball : jordan = soccer: ?
# Result from pretrained GloVe embeddings: egypt
#
# poetry : poet = music: ?
# Result from pretrained GloVe embeddings: composer
#
# england : capitalism = china: ?
# Result from pretrained GloVe embeddings: capitalism
#
# ship : sea = plane: ?
# Result from pretrained GloVe embeddings: plane
#
# physics : newton = biology: ?
# Result from pretrained GloVe embeddings: addison
#
# war : weapon = peace: ?
# Result from pretrained GloVe embeddings: precondition
#
# school : teacher = hospital: ?
# Result from pretrained GloVe embeddings: nurse
#
# pork : pig = beef: ?
# Result from pretrained GloVe embeddings: pig
#
# milwaukee : wisconsin = meridian: ?
# Result from pretrained GloVe embeddings: cherwell
#
# acting : oscar = music: ?
# Result from pretrained GloVe embeddings: music
#
# present : past = contemporary: ?
# Result from pretrained GloVe embeddings: inspired
#
# judaism : rabbi = christianity: ?
# Result from pretrained GloVe embeddings: isaac
#
# tragedy : sad = comedy: ?
# Result from pretrained GloVe embeddings: sitcom
#
# ireland : potatoes = italy: ?
# Result from pretrained GloVe embeddings: tomato
#
# sailing : boat = driving: ?
# Result from pretrained GloVe embeddings: car
#
# night : dark = day: ?
# Result from pretrained GloVe embeddings: bright
#
# motif : theme = detail: ?
# Result from pretrained GloVe embeddings: detail
#
# hypothesis : result = question: ?
# Result from pretrained GloVe embeddings: over
#
# black : color = triangle: ?
# Result from pretrained GloVe embeddings: pixel
#
# cold : hot = freezing: ?
# Result from pretrained GloVe embeddings: hot
#
# cat : kitten = dog: ?
# Result from pretrained GloVe embeddings: puppy
#
# france : europe = china: ?
# Result from pretrained GloVe embeddings: taiwan
#
# boy : girl = man: ?
# Result from pretrained GloVe embeddings: man
#
# tall : short = big: ?
# Result from pretrained GloVe embeddings: making
#
# master : apprentice = teacher: ?
# Result from pretrained GloVe embeddings: homemaker
#
# tree : plant = dog: ?
# Result from pretrained GloVe embeddings: factory
#
# knight : squire = professor: ?
# Result from pretrained GloVe embeddings: sociologist
#
# man : woman = mr: ?
# Result from pretrained GloVe embeddings: mr
#
# Wrong format of the analogy
#
# Result from pretrained GloVe embeddings: mr
#
# Wrong format of the analogy
#
# Result from pretrained GloVe embeddings: mr
#
# Wrong format of the analogy
#
# Result from pretrained GloVe embeddings: mr
#
# Wrong format of the analogy
#
# Result from pretrained GloVe embeddings: mr
#
# Wrong format of the analogy
#
# Result from pretrained GloVe embeddings: mr
#
# Wrong format of the analogy
#
# Result from pretrained GloVe embeddings: mr
#
# Wrong format of the analogy
#
# Result from pretrained GloVe embeddings: mr
#
# Wrong format of the analogy
#
# Result from pretrained GloVe embeddings: mr
#
# Wrong format of the analogy
#
# Result from pretrained GloVe embeddings: mr
#
# Wrong format of the analogy
#
# Result from pretrained GloVe embeddings: mr
#
# baseball : diamond = football: ?
# Result from pretrained GloVe embeddings: diamonds
#
# coffee : milk = toast: ?
# Result from pretrained GloVe embeddings: butter
#
# happy : sad = day: ?
# Result from pretrained GloVe embeddings: sad
#
# dolphin : ocean = eagle: ?
# Result from pretrained GloVe embeddings: atlantic
#
# north : south = right: ?
# Result from pretrained GloVe embeddings: put
#
# christian : church = muslim: ?
# Result from pretrained GloVe embeddings: holy
#
# pen : sword = love: ?
# Result from pretrained GloVe embeddings: sword
#
# match : fire = hammer: ?
# Result from pretrained GloVe embeddings: fire
#
# happy : sad = wet: ?
# Result from pretrained GloVe embeddings: foggy
#
# heaven : god = hell: ?
# Result from pretrained GloVe embeddings: hell
#
# fire : burning = ice: ?
# Result from pretrained GloVe embeddings: melting
#
# boat : sink = car: ?
# Result from pretrained GloVe embeddings: car
#
# three : four = five: ?
# Result from pretrained GloVe embeddings: six
#
# woods : acorn = orchard: ?
# Result from pretrained GloVe embeddings: casein
#
# picture : blurry = knife: ?
# Result from pretrained GloVe embeddings: pocketknife
#
# farm : dirt = city: ?
# Result from pretrained GloVe embeddings: inside
#
# drizzle : storm = wind: ?
# Result from pretrained GloVe embeddings: hurricane
#
# deer : doe = cow: ?
# Result from pretrained GloVe embeddings: leaked
#
# camera : picture = microphone: ?
# Result from pretrained GloVe embeddings: proudly
#
# friend : enemy = cat: ?
# Result from pretrained GloVe embeddings: predator
#
# bose : einstein = newton: ?
# Result from pretrained GloVe embeddings: einstein
#
# square : cube = triangle: ?
# Result from pretrained GloVe embeddings: helix
#
# linux : free = microsoft: ?
# Result from pretrained GloVe embeddings: seeking
#
# keyboard : type = mouse: ?
# Result from pretrained GloVe embeddings: humans
#
# coffee : bean = tea: ?
# Result from pretrained GloVe embeddings: curry
#
# michigan : lansing = illinois: ?
# Result from pretrained GloVe embeddings: evanston
#
# tree : bark = plant: ?
# Result from pretrained GloVe embeddings: plants
#
# hammer : nail = screwdriver: ?
# Result from pretrained GloVe embeddings: scissors
#
# dice : roll = coin: ?
# Result from pretrained GloVe embeddings: stamp
#
# mathematics : gauss = physics: ?
# Result from pretrained GloVe embeddings: popper
#
# boy : girl = man: ?
# Result from pretrained GloVe embeddings: man
#
# murder : suicide = knife: ?
# Result from pretrained GloVe embeddings: bullet
#
# dictionary : definition = novel: ?
# Result from pretrained GloVe embeddings: effect
#
# germany : hitler = china: ?
# Result from pretrained GloVe embeddings: jiang
#
# listen : deaf = look: ?
# Result from pretrained GloVe embeddings: deaf
#
# beer : alcohol = marijuana: ?
# Result from pretrained GloVe embeddings: alcohol
#
# america : canada = china: ?
# Result from pretrained GloVe embeddings: taiwan
#
# bread : butter = egg: ?
# Result from pretrained GloVe embeddings: eggs
#
# finance : money = technology: ?
# Result from pretrained GloVe embeddings: ability
#
# happy : smile = depressed: ?
# Result from pretrained GloVe embeddings: depressed
#
# tennis : racket = baseball: ?
# Result from pretrained GloVe embeddings: thrown
#
# Illinois : Springfield = Connecticut: ?
# Word not in library.
#
# bed : sleep = chair: ?
# Result from pretrained GloVe embeddings: hopkins
#
# mango : fruit = eggplant: ?
# Result from pretrained GloVe embeddings: cooked
#
# pen : write = scissor: ?
# Result from pretrained GloVe embeddings: compose
#
# snake : reptile = frog: ?
# Result from pretrained GloVe embeddings: amphibian
#
# nose : breathe = eye: ?
# Result from pretrained GloVe embeddings: someday
#
# hand : finger = foot: ?
# Result from pretrained GloVe embeddings: hoof
#
# watch : wrist = ring: ?
# Result from pretrained GloVe embeddings: forearm
#
# girlfriend : wife = boyfriend: ?
# Result from pretrained GloVe embeddings: husband
#
# pulse : heart = rhythm: ?
# Result from pretrained GloVe embeddings: hip
#
# sermons : priest = musicals: ?
# Result from pretrained GloVe embeddings: clown
#
# therapy : psychologist = cuisine: ?
# Result from pretrained GloVe embeddings: chef
#
# silence : sounds = vacuum: ?
# Result from pretrained GloVe embeddings: vacuum
#
# yin : daylight = yang: ?
# Result from pretrained GloVe embeddings: stopping
#
# documentation : governments = certification: ?
# Result from pretrained GloVe embeddings: nations
#
# taxonomy : biology = topology: ?
# Result from pretrained GloVe embeddings: geometry
#
# presidents : campaigns = generals: ?
# Result from pretrained GloVe embeddings: tactics
#
# prosecutor : accusations = defendant: ?
# Result from pretrained GloVe embeddings: false
#
# marxist : capitalism = capitalist: ?
# Result from pretrained GloVe embeddings: capitalist
#
# steel : carnegie = computer: ?
# Result from pretrained GloVe embeddings: harvard
#
# art : artist = music: ?
# Result from pretrained GloVe embeddings: songwriter
#
# fruit : tomato = vegetable: ?
# Result from pretrained GloVe embeddings: vegetable
#
# white : dwarf = gas: ?
# Result from pretrained GloVe embeddings: lpg
#
# america : burger = italy: ?
# Result from pretrained GloVe embeddings: unicredito
#
# geography : land = statistics: ?
# Result from pretrained GloVe embeddings: total
#
# australia : sydney = france: ?
# Result from pretrained GloVe embeddings: france
#
# washington : redwood = japan: ?
# Result from pretrained GloVe embeddings: tapir
#
# good : friend = bad: ?
# Result from pretrained GloVe embeddings: friend
#
# war : nuclear = peace: ?
# Result from pretrained GloVe embeddings: enrichment
#
# spain : spanish = poland: ?
# Result from pretrained GloVe embeddings: poland
#
# string : guitar = key: ?
# Result from pretrained GloVe embeddings: replaced
#
# hot : cold = bright: ?
# Result from pretrained GloVe embeddings: dark
#
# happy : sad = positive: ?
# Result from pretrained GloVe embeddings: positive
#
# elf : fair = dwarf: ?
# Result from pretrained GloVe embeddings: exhibit
#
# dirt : brown = leaf: ?
# Result from pretrained GloVe embeddings: leaf
#
# up : down = left: ?
# Result from pretrained GloVe embeddings: broke
#
# hungry : eat = tired: ?
# Result from pretrained GloVe embeddings: 'd
#
# teacher : school = doctor: ?
# Result from pretrained GloVe embeddings: doctor
#
# eye : see = finger: ?
# Result from pretrained GloVe embeddings: simply
#
# compactness : topology = differentiability: ?
# Result from pretrained GloVe embeddings: differentiability
#
# filibuster : holdup = gerrymandering: ?
# Result from pretrained GloVe embeddings: durazno
#
# miserly : generous = languid: ?
# Result from pretrained GloVe embeddings: generous
#
# happiness : ecstasy = unhappiness: ?
# Result from pretrained GloVe embeddings: snorting
#
# grape : fruit = tomato: ?
# Result from pretrained GloVe embeddings: soup
#
# sunrise : sunset = birth: ?
# Result from pretrained GloVe embeddings: marriage
#
# branch : tree = wheel: ?
# Result from pretrained GloVe embeddings: wheel
#
# dance : dancer = swim: ?
# Result from pretrained GloVe embeddings: swim
#
# chicago : illinois = houston: ?
# Result from pretrained GloVe embeddings: ohio
#
# excitement : quench = fire: ?
# Result from pretrained GloVe embeddings: extinguish
#
# shoe : boot = shirt: ?
# Result from pretrained GloVe embeddings: boot
#
# talk : sing = walk: ?
# Result from pretrained GloVe embeddings: walk
#
# proletariet : bourgeois = man: ?
# Word not in library.
#
# baby : adult = puppy: ?
# Result from pretrained GloVe embeddings: generalist
#
# novice : master = amateur: ?
# Result from pretrained GloVe embeddings: amateur
#
# short : tall = skinny: ?
# Result from pretrained GloVe embeddings: wiry
#
# thank : apologize = greet: ?
# Result from pretrained GloVe embeddings: enraged
#
# cow : herd = bird: ?
# Result from pretrained GloVe embeddings: bird
#
# basketball : court = football: ?
# Result from pretrained GloVe embeddings: appeals
#
# student : teacher = employee: ?
# Result from pretrained GloVe embeddings: employer
#
# illinois : chicago = california: ?
# Result from pretrained GloVe embeddings: francisco
#
# russia : putin = germany: ?
# Result from pretrained GloVe embeddings: helmut
#
# microsoft : windows = apple: ?
# Result from pretrained GloVe embeddings: window
#
# federer : tennis = ronaldo: ?
# Result from pretrained GloVe embeddings: ronaldo
#
# sushi : japan = lasagna: ?
# Result from pretrained GloVe embeddings: greece
#
# fish : water = bird: ?
# Result from pretrained GloVe embeddings: cloud
#
# black : white = dark: ?
# Result from pretrained GloVe embeddings: gray
#
# eyes : ears = see: ?
# Result from pretrained GloVe embeddings: probably
#
# firefighter : fire = doctor: ?
# Result from pretrained GloVe embeddings: to
#
# north : south = east: ?
# Result from pretrained GloVe embeddings: south
#
# methane : methanol = ethane: ?
# Result from pretrained GloVe embeddings: b20
#
# past : future = behind: ?
# Result from pretrained GloVe embeddings: challenge
#
# rusnok : czechia = singh: ?
# Result from pretrained GloVe embeddings: clique
#
# fermion : electron = boson: ?
# Result from pretrained GloVe embeddings: boson
#
# apple : us = huawei: ?
# Result from pretrained GloVe embeddings: militaries
#
# sociology : soft = physics: ?
# Result from pretrained GloVe embeddings: liquid
#
# key : lock = password: ?
# Result from pretrained GloVe embeddings: username
#
# aristotle : plato = plato: ?
# Result from pretrained GloVe embeddings: cratylus
#
# Australia : act = us: ?
# Word not in library.
#
# mexico : taco = china: ?
# Result from pretrained GloVe embeddings: snack
#
# boy : girl = man: ?
# Result from pretrained GloVe embeddings: man
#
# russia : moscow = china: ?
# Result from pretrained GloVe embeddings: shanghai
#
# hospital : nurse = school: ?
# Result from pretrained GloVe embeddings: graduate
#
# kitten : cat = puppy: ?
# Result from pretrained GloVe embeddings: dog
#
# breakfast : morning = dinner: ?
# Result from pretrained GloVe embeddings: afternoon
#
# movie : watch = book: ?
# Result from pretrained GloVe embeddings: papers
#
# comedy : funny = tragedy: ?
# Result from pretrained GloVe embeddings: tragic
#
# english : england = russian: ?
# Result from pretrained GloVe embeddings: moscow
#
# fraternity : male = sorority: ?
# Result from pretrained GloVe embeddings: female
#
# left : right = up: ?
# Result from pretrained GloVe embeddings: right
#
# olympia : washington = annapolis: ?
# Result from pretrained GloVe embeddings: discuss
#
# breakfast : morning = dinner: ?
# Result from pretrained GloVe embeddings: afternoon
#
# pen : writing = brush: ?
# Result from pretrained GloVe embeddings: work
#
# basketball : hoop = soccer: ?
# Result from pretrained GloVe embeddings: scheffer
#
# baltimore : ravens = pittsburgh: ?
# Result from pretrained GloVe embeddings: redskins
#
# coffee : mug = soup: ?
# Result from pretrained GloVe embeddings: :-)
#
# eggs : omelette = flour: ?
# Result from pretrained GloVe embeddings: jerkan
#
# santa : christmas = bunny: ?
# Result from pretrained GloVe embeddings: halloween
#
# economics : money = theology: ?
# Result from pretrained GloVe embeddings: giving
#
# sit : chair = sleep: ?
# Result from pretrained GloVe embeddings: sleep
#
# open : closed = near: ?
# Result from pretrained GloVe embeddings: nearby
#
# smart : intelligent = sly: ?
# Result from pretrained GloVe embeddings: playful
#
# mouth : eat = ear: ?
# Result from pretrained GloVe embeddings: ate
#
# dirt : brown = leaves: ?
# Result from pretrained GloVe embeddings: leaves
#
# summer : hot = winter: ?
# Result from pretrained GloVe embeddings: snow
#
# nurse : hospital = teacher: ?
# Result from pretrained GloVe embeddings: school
#
# thirsty : drink = hungry: ?
# Result from pretrained GloVe embeddings: drinks
#
# up : down = left: ?
# Result from pretrained GloVe embeddings: broke
#
# pencil : write = knife: ?
# Result from pretrained GloVe embeddings: child
#
# bed : bedroom = toilet: ?
# Result from pretrained GloVe embeddings: toilet
#
# Wrong format of the analogy
#
# Result from pretrained GloVe embeddings: toilet
#
# sonny : cher = simon: ?
# Result from pretrained GloVe embeddings: garfunkel
#
# quayle : bush = gore: ?
# Result from pretrained GloVe embeddings: clinton
#
# laurel : hardy = cheech: ?
# Result from pretrained GloVe embeddings: fickman
#
# batman : gotham = superman: ?
# Result from pretrained GloVe embeddings: excalibur
#
# pork : pig = beef: ?
# Result from pretrained GloVe embeddings: pig
#
# crow : murder = lion: ?
# Result from pretrained GloVe embeddings: robbery
#
# left : right = up: ?
# Result from pretrained GloVe embeddings: right
#
# paris : parisian = glasgow: ?
# Result from pretrained GloVe embeddings: bexley
#
# manicure : fingers = pedicure: ?
# Result from pretrained GloVe embeddings: toes
#
# austin : texas = topeka: ?
# Result from pretrained GloVe embeddings: wichita
#
# fruit : juice = milk: ?
# Result from pretrained GloVe embeddings: juice
#
# animal : zoo = plant: ?
# Result from pretrained GloVe embeddings: zoo
#
# england : london = china: ?
# Result from pretrained GloVe embeddings: beijing
#
# lip : lipstick = eye: ?
# Result from pretrained GloVe embeddings: lipstick
#
# restaurant : food = bar: ?
# Result from pretrained GloVe embeddings: reduce
#
# winter : ski = summer: ?
# Result from pretrained GloVe embeddings: golf
#
# weekday : work = weekend: ?
# Result from pretrained GloVe embeddings: trying
#
# hospital : doctor = school: ?
# Result from pretrained GloVe embeddings: teacher
#
# bank : money = museum: ?
# Result from pretrained GloVe embeddings: collection
#
# back : deadlift = legs: ?
# Result from pretrained GloVe embeddings: chitinous
#
# canada : ontario = england: ?
# Result from pretrained GloVe embeddings: yorkshire
#
# congress : congressman = senate: ?
# Result from pretrained GloVe embeddings: sen.
#
# congressman : election = senator: ?
# Result from pretrained GloVe embeddings: elections
#
# doctor : patient = pilot: ?
# Result from pretrained GloVe embeddings: pilots
#
# china : chinese = england: ?
# Result from pretrained GloVe embeddings: scottish
#
# china : chinese = canada: ?
# Result from pretrained GloVe embeddings: canada
#
# white : black = bright: ?
# Result from pretrained GloVe embeddings: dark
#
# white : color = black: ?
# Result from pretrained GloVe embeddings: colors
#
# poker : tournament = football: ?
# Result from pretrained GloVe embeddings: team
#
# bark : dog = meow: ?
# Result from pretrained GloVe embeddings: bash
#
# good : heaven = evil: ?
# Result from pretrained GloVe embeddings: daleks
#
# drop : rain = flake: ?
# Result from pretrained GloVe embeddings: salukvadze
#
# leaf : tree = petal: ?
# Result from pretrained GloVe embeddings: tree
#
# finger : hand = toe: ?
# Result from pretrained GloVe embeddings: hand
#
# calf : cow = lamb: ?
# Result from pretrained GloVe embeddings: fried
#
# moon : night = sun: ?
# Result from pretrained GloVe embeddings: morning
#
# hoof : horse = foot: ?
# Result from pretrained GloVe embeddings: ride
#
# hot : summer = cold: ?
# Result from pretrained GloVe embeddings: winter
#
# electron : atom = planet: ?
# Result from pretrained GloVe embeddings: universe
#
# summer : hot = winter: ?
# Result from pretrained GloVe embeddings: snow
#
# english : words = math: ?
# Result from pretrained GloVe embeddings: memorize
#
# tshirt : top = pants: ?
# Word not in library.
#
# eye : see = ear: ?
# Result from pretrained GloVe embeddings: literally
#
# hate : love = darkness: ?
# Result from pretrained GloVe embeddings: twilight
#
# hill : mountain = lake: ?
# Result from pretrained GloVe embeddings: lakes
#
# light : lamp = wind: ?
# Result from pretrained GloVe embeddings: furnace
#
# cloud : rain = sun: ?
# Result from pretrained GloVe embeddings: sun
#
# tv : watch = book: ?
# Result from pretrained GloVe embeddings: read
#
# jew : judaism = christian: ?
# Result from pretrained GloVe embeddings: christianity
#
# chicago : beijing = windy: ?
# Result from pretrained GloVe embeddings: beijing
#
# humanities : unemployed = science: ?
# Result from pretrained GloVe embeddings: seriously
#
# finance : evil = academia: ?
# Result from pretrained GloVe embeddings: immortal
#
# school : stress = vacation: ?
# Result from pretrained GloVe embeddings: disruption
#
# cow : pig = beef: ?
# Result from pretrained GloVe embeddings: beef
#
# cow : beef = pig: ?
# Result from pretrained GloVe embeddings: beef
#
# beer : alcohol = weed: ?
# Result from pretrained GloVe embeddings: weed
#
# banker : powerpoint = engineer: ?
# Result from pretrained GloVe embeddings: computer-based
#
# class : studying = gym: ?
# Result from pretrained GloVe embeddings: gym
#
# machine : learning = human: ?
# Result from pretrained GloVe embeddings: understanding
#
# father : doctor = mother: ?
# Result from pretrained GloVe embeddings: nurse
#
# man : programmer = woman: ?
# Result from pretrained GloVe embeddings: prodigy
#
# dog : bark = cat: ?
# Result from pretrained GloVe embeddings: twigs
#
# chicken : eggs = humans: ?
# Result from pretrained GloVe embeddings: organisms
#
# shard : pottery = splinter: ?
# Result from pretrained GloVe embeddings: tribes
#
# chicago : illinois = milwaukee: ?
# Result from pretrained GloVe embeddings: ohio
#
# stars : cosmos = dirt: ?
# Result from pretrained GloVe embeddings: irrigating
#
# eraser : pencil = hat: ?
# Result from pretrained GloVe embeddings: shirt
#
# christmas : december = halloween: ?
# Result from pretrained GloVe embeddings: february
#
# hitler : germany = stalin: ?
# Result from pretrained GloVe embeddings: austria

# %% [markdown]
# ## (e) Visualize only the pretrained GloVe embeddings in two dimensions

# %%
words_ = p_vectors.keys()
W = p_vectsRDD.map(lambda x: np.array(x[1])).collect()

# %%
tsne = TSNE(n_components=2, random_state=0)
np.set_printoptions(suppress=True)
Y = tsne.fit_transform(W[:1000])
plt.scatter(Y[:, 0], Y[:, 1])
for label, x, y in zip(words, Y[:, 0], Y[:, 1]):
    plt.annotate(label, xy=(x, y), xytext=(0, 0),textcoords='offset points')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# In this tiny segment of words, we are able to observe that words that surround "parliament" include "go", "territory", "different", "future", "notable", "public", "problem", "independence", "minister" and etc. It's apparent that these words are often used close to "parliament". For example, "go to parliament", "the parliament discuss territory problems", "different parliament could lead to different future".

# %%
spark.stop()
